# %% [markdown]
# # Import Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import pandas and matplotlib**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![kickstarter-logo.jpg](data:image/jpeg;base64,...)
#
# **Kickstarter คืออะไร?** <br>
# Kickstarter เป็นแพลตฟอร์มสำหรับให้คน 2 ฝั่งได้มาเจอกันเพื่อการสร้างสรรค์นวัตกรรมใหม่ๆ
# ฝั่งแรก คือ คนที่มีไอเดีย แต่ไม่มีเงินพอที่จะสร้างธุรกิจ แค่เรานำผลงานของเราไปวางอยู่บนระบบนี้ ทุกคนก็จะสามารถเห็นผลงานของเราได้
# ซึ่งประเภทของผลงานที่ทาง Kickstarter ให้มาเสนอในแพลตฟอร์มนี้จะเป็นพวก ภาพยนตร์ ดนตรี เกม การ์ตูน เทคโนโลยี อาหาร งานฝีมือ และ ศิลปะ
# และอีกฝั่งก็จะเป็น บุคคลทั่วไป ที่เห็นผลงานต่างๆ บนแพลตฟอร์มนี้ แล้วรู้สึกสนใจและอยากที่จะสนับสนุนไอเดียดีๆ เหล่านี้<br>
# *refference: https://www.longtunman.com/8056*

# %% [markdown]
# **Read data by using pandas**

# %%
df = pd.read_csv('/content/drive/MyDrive/My IT KMITL Works/Lecture materials/Python for DS and ML/66-1/WEEK 4 - Pandas/data/ks-projects-201801.csv')

# %% [markdown]
# **Meta Data** <br>
# ข้อมูลที่ใช้เป็นข้อมูลของ Kick starter ซึ่งประกอบไปด้วย column ทั้งหมด 14
# columns <br>
# 1. name : ชื่อของโปรเจคที่มาเสนอทุน
# 2. category : หมวดหมู่ของโปรเจค
# 3. main category : หมวดหมู่หลักของโปรเจค
# 4. currency : สกุลเงินที่โปรเจคนั้นใช้
# 5. deadline : วันที่โปรเจคนี้จะสิ้นสุด
# 6. goal : จำนวนเงินที่เจ้าของโปรเจคต้องการ (สกุลเงินต้นทาง)
# 7. launched : วันเริ่มโปรเจค
# 8. pledged : จำนวนเงินสนับสนุนที่ได้รับ (สกุลเงินต้นทาง)
# 9. state : สถานะของโปรเจค
# 10. backers : จำนวนผู้สนับสนุน
# 11. country : ประเทศ
# 12. usd pledged : จำนวนเงินที่ถูกสนับสนุน ในสกุลเงิน US dollar
# 13. usd pledged real : จำนวนเงินที่ถูกสนับสนุนที่ได้รับจริง ในสกุลเงิน US dollar
# 14. usd goal real : จำนวนเงินเป้าหมายในสกุลเงิน US dollar

# %% [markdown]
# **แสดงผล 5 แถวแรกของ dataframe**

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %% [markdown]
# **แสดงผล 5 แถวสุดท้ายของ dataframe**

# %%
df.tail()
# Out:
#                ID                                               name  \
# 378656  999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657  999977640                                          The Tribe
# 378658  999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659  999987933                           BioDefense Education Kit
# 378660  999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# ...

# %% [markdown]
# **แสดงผลข้อมูลพื้นฐานของ dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                378661 non-null  int64
#  1   name              378657 non-null  object
#  2   category          378661 non-null  object
#  3   main_category     378661 non-null  object
#  4   currency          378661 non-null  object
#  5   deadline          378661 non-null  object
#  6   goal              378661 non-null  float64
#  7   launched          378661 non-null  object
#  8   pledged           378661 non-null  float64
#  9   state             378661 non-null  object
#  10  backers           378661 non-null  int64
#  11  country           378661 non-null  object
#  12  usd pledged       374864 non-null  float64
#  13  usd_pledged_real  378661 non-null  float64
#  14  usd_goal_real     378661 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# ...

# %% [markdown]
# **Hint:** Pandas to_datetime() function helps to convert string Datetime into Python Datetime object.

# %%
data = pd.Series(['3/11/1998', '3/12/1999', '3/13/2000'])
data
# Out:
# 0    3/11/1998
# 1    3/12/1999
# 2    3/13/2000
# dtype: object

# %%
data = pd.to_datetime(data)
data
# Out:
# 0   1998-03-11
# 1   1999-03-12
# 2   2000-03-13
# dtype: datetime64[ns]

# %% [markdown]
# **EX: แปลง Data types ของ column deadline และ launched ให้อยู่ในรูปแบบของ datetime และแสดงผลลัพท์หลังจากการเปลี่ยน Data types**

# %%
# Convert 'deadline'

# %%
# Convert 'launched'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                378661 non-null  int64
#  1   name              378657 non-null  object
#  2   category          378661 non-null  object
#  3   main_category     378661 non-null  object
#  4   currency          378661 non-null  object
#  5   deadline          378661 non-null  datetime64[ns]
#  6   goal              378661 non-null  float64
#  7   launched          378661 non-null  datetime64[ns]
#  8   pledged           378661 non-null  float64
#  9   state             378661 non-null  object
#  10  backers           378661 non-null  int64
#  11  country           378661 non-null  object
#  12  usd pledged       374864 non-null  float64
#  13  usd_pledged_real  378661 non-null  float64
#  14  usd_goal_real     378661 non-null  float64
# ...

# %% [markdown]
# **Number format cheat sheet**
# ![Screen Shot 2564-04-10 at 06.25.28.png](data:image/png;base64,...)

# %% [markdown]
# **แสดงผลจำนวนเงินสนับสนุนที่ได้รับจริง (usd_pledged_real) มากที่สุด**

# %%
#Code here
# Out:
# '20,338,986.27 usd'

# %% [markdown]
# **EX: แสดงผลจำนวนเงินสนับสนุนที่ได้รับจริง (usd_pledged_real) น้อยที่สุด**

# %%
#Code here
# Out:
# '0.00 usd'

# %% [markdown]
# **EX: แสดงผลจำนวนเงินสนับสนุนที่ได้รับจริง (usd_pledged_real) เฉลี่ย**

# %%
#Code here
# Out:
# '9,058.92 usd'

# %% [markdown]
# **Hint:** Pandas unique() function on the column of interest. And it will return NumPy array with unique values of the column.

# %%
data = pd.Series([2, 1, 3, 3, 4, 2, 3, 1])
pd.unique(data)
# Out:
# array([2, 1, 3, 4])

# %% [markdown]
# **Hint:** Pandas nunique() function return Series with number of distinct observations over requested axis.

# %%
data = pd.DataFrame({"A":[14, 4, 14, 4, 1],"B":[5, 87, 54, 3, 2],"C":[20, 20, 9, 9, 9], "D":[14, 3, 6, 4, 6]})
data
# Out:
#     A   B   C   D
# 0  14   5  20  14
# 1   4  87  20   3
# 2  14  54   9   6
# 3   4   3   9   4
# 4   1   2   9   6

# %%
data.nunique() #axis=0
# Out:
# A    3
# B    5
# C    2
# D    4
# dtype: int64

# %%
data.nunique(axis=1)
# Out:
# 0    3
# 1    4
# 2    4
# 3    3
# 4    4
# dtype: int64

# %% [markdown]
# **EX: แสดงผลสถานะของ Project ทั้งหมดว่ามีทั้งหมดกี่สถานะ (state) และประกอบไปด้วยสถานะอะไรบ้าง**
#
# **Hint:** [Series.unique](https://pandas.pydata.org/docs/reference/api/pandas.Series.nunique.html)

# %%
# Unique number
# Out:
# 6

# %%
# Unique states
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'undefined',
#        'suspended'], dtype=object)

# %% [markdown]
# **EX: ลบ Column pledged, usd_pledged และ usd_pledged_real ออกจาก Data frame พร้อมแสดงผลลัพท์หลังจากการลบ**

# %%
#Code here
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency   deadline     goal  \
# ...

# %% [markdown]
# **EX: แสดงผลว่าแต่ละสถานะ (state) มีจำนวน Project เท่าไหร่**
#
# **Hint:** [Series.value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html)

# %%
#Code here
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %% [markdown]
# **Hint:** Pandas sort_values() function sorts a data frame in Ascending or Descending order of passed Column.

# %%
data = pd.DataFrame({'col1': ['A', 'A', 'B', 'E', 'D', 'C'],
                              'col2': [2, 1, 9, 8, 7, 4],
                              'col3': [0, 1, 9, 4, 2, 3],
                              'col4': ['a', 'B', 'c', 'D', 'e', 'F']})
data
# Out:
#   col1  col2  col3 col4
# 0    A     2     0    a
# 1    A     1     1    B
# 2    B     9     9    c
# 3    E     8     4    D
# 4    D     7     2    e
# 5    C     4     3    F

# %%
data.sort_values('col1', ascending=False)
# Out:
#   col1  col2  col3 col4
# 3    E     8     4    D
# 4    D     7     2    e
# 5    C     4     3    F
# 2    B     9     9    c
# 0    A     2     0    a
# 1    A     1     1    B

# %% [markdown]
# **EX: แสดงผลโปรเจคที่มีสถานะ (state)  successful และได้รับเงินสนับสนุน (usd_pledged_real) สูงสุด 10 อันดับแรก**

# %%
#Code here

# %% [markdown]
# **EX: ค้นหาว่าใน 10 อันดับข้างต้นมีกี่โปรเจคที่ได้รับเงินสนับสนุน (usd_pledged_real) มากกว่าเป้าหมาย (usd_goal_real) ที่ตั้งไว้**

# %%
#Code here

# %% [markdown]
# **EX: จากข้อด้านบน สร้าง column ใหม่แสดงจำนวนเงินสนับสนุน (usd_pledged_real) ของโปรเจคเหล่านั้นว่าได้มากกว่าที่ตั้งไว้ (usd_goal_real) เท่าใด**

# %%
#Code here

# %% [markdown]
# **EX: แสดงผลหมวดหมู่หลัก (main_category) 5 ประเภทแรกที่สามารถระดมทุน (usd_pledged_real) ได้เกินเป้าหมาย (usd_goal_real) ที่ตั้งไว้**

# %%
# Out:
# main_category
# Music           24649
# Film & Video    23016
# Games           12655
# Publishing      11970
# Art             11147
# dtype: int64

# %% [markdown]
# **Hint:** We can plot a dataframe using the plot() method.
#
# ```python
# df['main_category'].value_counts(ascending=False)[:5].plot(kind='bar')
# ```

# %% [markdown]
# **EX: พล็อตกราฟแท่งแสดงผลหมวดหมู่หลัก (main_category) 5 ประเภทแรกที่สามารถระดมทุน (usd_pledged_real) ได้เกินเป้าหมาย (usd_goal_real) ที่ตั้งไว้**

# %%
#Code here
