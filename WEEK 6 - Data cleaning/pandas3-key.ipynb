# %% [markdown]
# # Pandas (3)
#
# Let's learn more features of Pandas for data cleaning
#
# **Outline**
# - Working with Text Data
# - Working with Missing Data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Working with text data
# There are two ways to store text data in pandas:
#
# - `object` -dtype NumPy array.
# - `StringDtype` extension type.

# %%
pd.Series(["a", "b", "c"])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(["a", "b", "c"], dtype="string") # or dtype=pd.StringDtype()
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %% [markdown]
# ### String methods
#
# Series and Index are equipped with a set of string processing methods that make it easy to operate on each element of the array.
#
# These are accessed via the `str` attribute and generally have names matching the equivalent (scalar) built-in string methods.
#
# The full list of available methods can be found [HERE](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary)

# %%
s = pd.Series(
    ["A", "B", "C", np.nan, "CABA", "dog", "cat"], dtype="string"
)

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    <NA>
# 4    caba
# 5     dog
# 6     cat
# dtype: string

# %%
s.str.upper()
# Out:
# 0       A
# 1       B
# 2       C
# 3    <NA>
# 4    CABA
# 5     DOG
# 6     CAT
# dtype: string

# %%
s.str.len()
# Out:
# 0       1
# 1       1
# 2       1
# 3    <NA>
# 4       4
# 5       3
# 6       3
# dtype: Int64

# %% [markdown]
# ### Splitting and replacing strings
#
# Methods like `split` return a Series of lists:

# %%
s2 = pd.Series(["a_b_c", "c_d_e", np.nan, "f_g_h"], dtype="string")
s2.str.split("_")
# Out:
# 0    [a, b, c]
# 1    [c, d, e]
# 2         <NA>
# 3    [f, g, h]
# dtype: object

# %% [markdown]
# Elements in the split lists can be accessed using `get` or `[]` notation:

# %%
print(s2.str.split("_").str.get(1))
print(s2.str.split("_").str[0])
# Out:
# 0       b
# 1       d
# 2    <NA>
# 3       g
# dtype: object
# 0       a
# 1       c
# 2    <NA>
# 3       f
# dtype: object

# %% [markdown]
# It is easy to expand this to return a DataFrame using `expand` option.

# %%
s2.str.split("_", expand=True)
# Out:
#       0     1     2
# 0     a     b     c
# 1     c     d     e
# 2  <NA>  <NA>  <NA>
# 3     f     g     h

# %%
s3 = pd.Series(
    ["A", "B", "C", "Aaba", "Baca", "", np.nan, "CABA", "dog", "cat"],
    dtype="string",
)

# %%
s3.str.replace('A', 'XX', regex=False)
# Out:
# 0        XX
# 1         B
# 2         C
# 3     XXaba
# 4      Baca
# 5
# 6      <NA>
# 7    CXXBXX
# 8       dog
# 9       cat
# dtype: string

# %%
# Optionally replace can use Regex
s3.str.replace("^.a|dog", "XX-XX ", case=False, regex=True)
# Out:
# 0           A
# 1           B
# 2           C
# 3    XX-XX ba
# 4    XX-XX ca
# 5
# 6        <NA>
# 7    XX-XX BA
# 8      XX-XX
# 9     XX-XX t
# dtype: string

# %% [markdown]
# ### Concatenation

# %%
s = pd.Series(["a", "b", "c", "d"], dtype="string")
print(s)
s.str.cat(sep=",")
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: string
# 'a,b,c,d'

# %% [markdown]
# By default, missing values are ignored. Using na_rep, they can be given a representation:

# %%
t = pd.Series(["a", "b", np.nan, "d"], dtype="string")
t.str.cat(sep=",", na_rep="-")
# Out:
# 'a,b,-,d'

# %% [markdown]
# Concatenating a Series and something list-like into a Series.
#
# The first argument to cat() can be a list-like object, provided that it matches the length of the calling Series.

# %%
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: string

# %%
s.str.cat(others=["A", "B", "C", "D"])
# Out:
# 0    aA
# 1    bB
# 2    cC
# 3    dD
# dtype: string

# %% [markdown]
# **EX:** จาก DataFrame ที่กำหนด ให้แยกชื่อเต็ม `name` เป็น 3 columns คือ `first` `middle` และ `last`

# %%
df = pd.DataFrame({
    'name': ['Alberto  Franco','Gino Ann Mcneill','Ryan  Parkes', 'Eesha Artur Hinton', 'Syed  Wharton'],
    'date_of_birth': ['17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})

df
# Out:
#                  name date_of_birth   age
# 0     Alberto  Franco    17/05/2002  18.5
# 1    Gino Ann Mcneill    16/02/1999  21.2
# 2        Ryan  Parkes    25/09/1998  22.5
# 3  Eesha Artur Hinton    11/05/2002  22.0
# 4       Syed  Wharton    15/09/1997  23.0

# %%
# YOUR CODE HERE
df2 = df['name'].str.split(' ', expand=True)
df2.columns = ['first', 'middle', 'last']
df2
# Out:
#      first middle     last
# 0  Alberto          Franco
# 1     Gino    Ann  Mcneill
# 2     Ryan          Parkes
# 3    Eesha  Artur   Hinton
# 4     Syed         Wharton

# %%
pd.concat([df, df2], axis=1)
# Out:
#                  name date_of_birth   age    first middle     last
# 0     Alberto  Franco    17/05/2002  18.5  Alberto          Franco
# 1    Gino Ann Mcneill    16/02/1999  21.2     Gino    Ann  Mcneill
# 2        Ryan  Parkes    25/09/1998  22.5     Ryan          Parkes
# 3  Eesha Artur Hinton    11/05/2002  22.0    Eesha  Artur   Hinton
# 4       Syed  Wharton    15/09/1997  23.0     Syed         Wharton

# %% [markdown]
# **EX:** Remove whitespaces, left sided whitespaces and right sided whitespaces of the string values of a given pandas series.

# %%
color = pd.Index([' Green', 'Black ', ' Red ', 'White', ' Pink '])
color
# Out:
# Index([' Green', 'Black ', ' Red ', 'White', ' Pink '], dtype='object')

# %%
# YOUR CODE HERE
color.str.strip()
# Out:
# Index(['Green', 'Black', 'Red', 'White', 'Pink'], dtype='object')

# %% [markdown]
# **EX:** Concatenating address with name column using `', '` for separator

# %%
df = pd.DataFrame({'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
                   'Age':[27, 24, 22, 32],
                   'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
                   'Qualification':['Msc', 'MA', 'MCA', 'Phd']})
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
# YOUR CODE HERE
df['Name'] = df['Name'].str.cat(sep=', ', others=df['Address'])
df
# Out:
#                 Name  Age    Address Qualification
# 0        Jai, Nagpur   27     Nagpur           Msc
# 1     Princi, Kanpur   24     Kanpur            MA
# 2  Gaurav, Allahabad   22  Allahabad           MCA
# 3      Anuj, Kannuaj   32    Kannuaj           Phd

# %% [markdown]
# ## Working with missing data

# %%
people = {
    'first': ['Bundit', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['Thanasopon', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['bundit@it.kmitl.ac.th', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': [np.nan, 55, 63, 36, None, None, 'Missing']
}

df = pd.DataFrame(people)
df
df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %% [markdown]
# Pandas does not consider "Missing" and "NA" are not considered missing values.
#
# **However, `None` and `np.nan` are missing values.**

# %%
df
# Out:
#     first        last                  email      age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th      NaN
# 1    Jane         Doe      JaneDoe@email.com       55
# 2    John         Doe      JohnDoe@email.com       63
# 3   Chris     Schafer                   None       36
# 4     NaN         NaN                    NaN     None
# 5    None         NaN    Anonymous@email.com     None
# 6      NA     Missing                     NA  Missing

# %%
df.isna() # or isnull()
# Out:
#    first   last  email    age
# 0  False  False  False   True
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6  False  False  False  False

# %%
df.isna().sum()
# Out:
# first    2
# last     2
# email    2
# age      3
# dtype: int64

# %%
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
df
# Out:
#     first        last                  email   age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th   NaN
# 1    Jane         Doe      JaneDoe@email.com  55.0
# 2    John         Doe      JohnDoe@email.com  63.0
# 3   Chris     Schafer                   None  36.0
# 4     NaN         NaN                    NaN   NaN
# 5    None         NaN    Anonymous@email.com   NaN
# 6     NaN         NaN                    NaN   NaN

# %%
df.dropna(axis=0, how="all") # default how="any"
# Out:
#     first        last                  email   age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th   NaN
# 1    Jane         Doe      JaneDoe@email.com  55.0
# 2    John         Doe      JohnDoe@email.com  63.0
# 3   Chris     Schafer                   None  36.0
# 5    None         NaN    Anonymous@email.com   NaN

# %%
# ต้องมี data point ที่ไม่ใช่ NaN >= 2 ตัวจึงจะเก็บไว้
df.dropna(axis=0, thresh=2)
# Out:
#     first        last                  email   age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th   NaN
# 1    Jane         Doe      JaneDoe@email.com  55.0
# 2    John         Doe      JohnDoe@email.com  63.0
# 3   Chris     Schafer                   None  36.0

# %% [markdown]
# **EX: ลอง drop ข้อมูล column สำหรับ column ที่มีค่า NaN มากกว่า 3 ตัว**

# %%
df.dropna(axis=1, thresh=4)
# Out:
#     first        last                  email
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th
# 1    Jane         Doe      JaneDoe@email.com
# 2    John         Doe      JohnDoe@email.com
# 3   Chris     Schafer                   None
# 4     NaN         NaN                    NaN
# 5    None         NaN    Anonymous@email.com
# 6     NaN         NaN                    NaN

# %% [markdown]
# สามารถเลือก drop โดยดูค่า NaN เฉพาะบาง column โดยการกำหนด `subset`

# %%
df.dropna(axis=0, how='any', subset=['email', 'age'])
# Out:
#   first last              email   age
# 1  Jane  Doe  JaneDoe@email.com  55.0
# 2  John  Doe  JohnDoe@email.com  63.0

# %% [markdown]
# We can replace NaN with a specific value with `fillna()` which will replace all NaN in the dataframe.

# %%
df.fillna('MISSING')
# Out:
#      first        last                  email      age
# 0   Bundit  Thanasopon  bundit@it.kmitl.ac.th  MISSING
# 1     Jane         Doe      JaneDoe@email.com     55.0
# 2     John         Doe      JohnDoe@email.com     63.0
# 3    Chris     Schafer                MISSING     36.0
# 4  MISSING     MISSING                MISSING  MISSING
# 5  MISSING     MISSING    Anonymous@email.com  MISSING
# 6  MISSING     MISSING                MISSING  MISSING

# %% [markdown]
# Let's check data types of each column.

# %%
df
# Out:
#     first        last                  email   age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th   NaN
# 1    Jane         Doe      JaneDoe@email.com  55.0
# 2    John         Doe      JohnDoe@email.com  63.0
# 3   Chris     Schafer                   None  36.0
# 4     NaN         NaN                    NaN   NaN
# 5    None         NaN    Anonymous@email.com   NaN
# 6     NaN         NaN                    NaN   NaN

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-50-ea46a3652da6> in <cell line: 1>()
# ----> 1 df['age'].astype(int)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6532         else:
#    6533             # else, only a single dtype is given
# -> 6534             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412             copy = False
#     413
# --> 414         return self.apply(
#     415             "astype",
#     416             dtype=dtype,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     352                 applied = b.apply(f, **kwargs)
#     353             else:
# --> 354                 applied = getattr(b, f)(**kwargs)
#     355             result_blocks = extend_blocks(applied, result_blocks)
#     356
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow)
#     614         values = self.values
#     615
# --> 616         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     617
#     618         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     236
#     237     try:
# --> 238         new_values = astype_array(values, dtype, copy=copy)
#     239     except (ValueError, TypeError):
#     240         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     181
#     182     else:
# --> 183         values = _astype_nansafe(values, dtype, copy=copy)
#     184
#     185     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#      99
#     100     elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101         return _astype_float_to_int_nansafe(arr, dtype, copy)
#     102
#     103     elif arr.dtype == object:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in _astype_float_to_int_nansafe(values, dtype, copy)
#     144     """
#     145     if not np.isfinite(values).all():
# --> 146         raise IntCastingNaNError(
#     147             "Cannot convert non-finite values (NA or inf) to integer"
#     148         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df['age'] = df['age'].astype(float) # Nan จะไม่มีปัญหากับ float
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df
# Out:
#     first        last                  email   age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th   NaN
# 1    Jane         Doe      JaneDoe@email.com  55.0
# 2    John         Doe      JohnDoe@email.com  63.0
# 3   Chris     Schafer                   None  36.0
# 4     NaN         NaN                    NaN   NaN
# 5    None         NaN    Anonymous@email.com   NaN
# 6     NaN         NaN                    NaN   NaN

# %% [markdown]
# สำหรับ column ที่มีค่าเป็นตัวเลข เราสามารถแทนค่า `NaN` ด้วยค่ากลางเช่น mean หรือ median

# %%
df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df['age'] = round(df['age'])
df
# Out:
#     first        last                  email   age
# 0  Bundit  Thanasopon  bundit@it.kmitl.ac.th  51.0
# 1    Jane         Doe      JaneDoe@email.com  55.0
# 2    John         Doe      JohnDoe@email.com  63.0
# 3   Chris     Schafer                   None  36.0
# 4     NaN         NaN                    NaN  51.0
# 5    None         NaN    Anonymous@email.com  51.0
# 6     NaN         NaN                    NaN  51.0

# %% [markdown]
# ## Handling datetime

# %%
df = pd.read_csv('eth_data.csv')

# %%
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.dtypes
# Out:
# Date       object
# Symbol     object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %% [markdown]
# **Datetime string format** : [Doc](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 16901   2018-04-09 15:00:00
# 16902   2018-04-09 14:00:00
# 16903   2018-04-09 13:00:00
# 16904   2018-04-09 12:00:00
# 16905   2018-04-09 11:00:00
# Name: Date, Length: 16906, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Symbol            object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
# Get day of week
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('704 days 09:00:00')

# %% [markdown]
# **EX: สร้าง column ใหม่ที่เก็บ weekday ของ Date**
#
# Hint: [Series.dt.day_name()](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.day_name.html)

# %%
df["Weekday"] = df["Date"].dt.day_name()
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 16901 2018-04-09 15:00:00  ETHUSD  394.24  399.01  393.00  397.76  1909337.36
# 16902 2018-04-09 14:00:00  ETHUSD  393.40  394.26  388.00  394.24  2429049.26
# 16903 2018-04-09 13:00:00  ETHUSD  394.48  396.25  393.25  393.40  1881646.37
# 16904 2018-04-09 12:00:00  ETHUSD  395.16  399.32  392.12  394.48  2494862.70
# 16905 2018-04-09 11:00:00  ETHUSD  402.75  402.75  393.95  395.16      440.00
#
#       Weekday
# 0      Friday
# 1      Friday
# 2      Friday
# 3      Friday
# 4      Friday
# ...       ...
# 16901  Monday
# 16902  Monday
# 16903  Monday
# 16904  Monday
# 16905  Monday
#
# [16906 rows x 8 columns]

# %% [markdown]
# **Filtering Datetime**

# %%
df[df['Date'] >= '2020-02-01']
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1000 2020-02-01 04:00:00  ETHUSD  183.16  183.49  181.34  181.74   706490.86
# 1001 2020-02-01 03:00:00  ETHUSD  183.61  183.81  182.41  183.16   279177.55
# 1002 2020-02-01 02:00:00  ETHUSD  183.59  184.00  181.93  183.61  1829192.09
# 1003 2020-02-01 01:00:00  ETHUSD  181.06  183.64  180.98  183.59   946295.21
# 1004 2020-02-01 00:00:00  ETHUSD  179.74  181.41  179.00  181.06   637332.52
#
#        Weekday
# 0       Friday
# 1       Friday
# 2       Friday
# 3       Friday
# 4       Friday
# ...        ...
# 1000  Saturday
# 1001  Saturday
# 1002  Saturday
# 1003  Saturday
# 1004  Saturday
#
# [1005 rows x 8 columns]

# %% [markdown]
# **EX: Filter ข้อมูลระหว่างวันที่ `2019-07-01` ถึง `2019-12-31`**

# %%
df[(df['Date'] >= '2019-07-01') & (df['Date'] <= '2019-12-31')]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 1772 2019-12-31 00:00:00  ETHUSD  131.10  131.10  130.31  131.03   345342.78
# 1773 2019-12-30 23:00:00  ETHUSD  131.97  132.19  130.76  131.10   301891.01
# 1774 2019-12-30 22:00:00  ETHUSD  131.46  131.97  131.46  131.97   185843.91
# 1775 2019-12-30 21:00:00  ETHUSD  131.44  131.73  131.21  131.46   179063.98
# 1776 2019-12-30 20:00:00  ETHUSD  130.72  131.93  130.67  131.44   549417.77
# ...                  ...     ...     ...     ...     ...     ...         ...
# 6160 2019-07-01 04:00:00  ETHUSD  298.15  299.80  295.57  297.97  1036527.82
# 6161 2019-07-01 03:00:00  ETHUSD  296.99  301.32  295.81  298.15  1465814.16
# 6162 2019-07-01 02:00:00  ETHUSD  293.93  298.58  292.15  296.99  1367256.41
# 6163 2019-07-01 01:00:00  ETHUSD  295.11  298.70  293.53  293.93  2293925.50
# 6164 2019-07-01 00:00:00  ETHUSD  290.07  295.25  286.69  295.11  4209855.92
#
#       Weekday
# 1772  Tuesday
# 1773   Monday
# 1774   Monday
# 1775   Monday
# 1776   Monday
# ...       ...
# 6160   Monday
# 6161   Monday
# 6162   Monday
# 6163   Monday
# 6164   Monday
#
# [4393 rows x 8 columns]
